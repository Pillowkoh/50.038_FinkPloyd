# %%
import os
import math
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import tensorflow as tf
from tensorflow import keras

with open('mfcc_data.npy', 'rb') as f:
    mfcc_data = np.load(f)
print(f'MFCC data shape: {mfcc_data.shape}')

label_path = 'deam-dataset/DEAM_Annotations/annotations/annotations averaged per song/song_level/';
labels_1_2000 = pd.read_csv(os.path.join(label_path, 'static_annotations_averaged_songs_1_2000.csv'))
labels_2000_2058 = pd.read_csv(os.path.join(label_path,'static_annotations_averaged_songs_2000_2058.csv'))
labels = pd.concat([labels_1_2000, labels_2000_2058], ignore_index=True, sort=False)
labels = labels[labels_1_2000.columns]
labels.columns = labels.columns.str.replace(' ', '')

valence = labels['valence_mean'].to_numpy()
arousal = labels['arousal_mean'].to_numpy()
y = np.vstack([valence, arousal]).T
print(f'Labels shape: {y.shape}')
# Out:
# MFCC data shape: (1802, 1920, 20)
# Labels shape: (1802, 2)

# %%
from tqdm import tqdm
import csv

sample_labels_path = 'deam-dataset/DEAM_Annotations/annotations/annotations averaged per song/dynamic'
sample_valence = pd.read_csv(os.path.join(sample_labels_path, 'valence.csv')).T
sample_arousal = pd.read_csv(os.path.join(sample_labels_path, 'arousal.csv')).T

def categorise_sample_labels(v, a, bound):
  if v > bound and a > bound:
    return 0
  elif v > bound and a < bound:
    return 1
  elif v < bound and a > bound:
    return 2
  elif v < bound and a < bound:
    return 3
  else:
    return 4

# returns opensmile feature data and categorised labels (per sample basis)
# in a dictionary format, where keys are the names (2, 3, ...) of the audio files in the dataset
def get_data_and_labels_for_each_sample_in_song(valence, arousal):
  all_labels = {}
  all_data = {}
  dir = 'features/'

  for i in range(len(valence.columns)):
    labels = []
    data = []

    filename = str(int(valence[i]['song_id']))+'.csv'
    f = open(dir+filename, 'r')
    reader = list(csv.reader(f, delimiter=';'))

    if len(reader) < 91:
      pad = [reader[len(reader)-1]]*(91-len(reader))
      reader = reader+pad
    
    for num in range(15000, 45001, 500):
      v = valence[i]['sample_'+str(num)+'ms']
      a = arousal[i]['sample_'+str(num)+'ms']

      category = categorise_sample_labels(v,a,0.1)
      # removes sample of category 4 from reader
      if category != 4:
        labels.append(category)
        data.append(reader[num//500])

    #cutting or padding if len(labels) != 60
    if len(labels) > 60:
       labels = labels[:60]
       data = data[:60]
    elif len(labels) < 60:
      #most_common_no = max(set(labels), key = labels.count)
      labels += [labels[-1]]*(60-len(labels))
      data += [data[-1]]*(60-len(data))

    if len(labels) != len(data):
      print(len(labels), len(data))
    
    all_labels[int(valence[i]['song_id'])] = keras.utils.to_categorical(labels, num_classes=4)
    all_data[int(valence[i]['song_id'])] = data

  return all_labels, all_data
sample_labels, deam_features_data = get_data_and_labels_for_each_sample_in_song(sample_valence, sample_arousal)

# %%
# builds a numpy array for opensmile features and sampling labels respectively
def build_X_y(all_data, all_labels):
  X = []
  y = []
  for key in all_data.keys():
    X.append(all_data[key])
    y.append(all_labels[key])

  X = np.array(X, dtype=np.float32, ndmin=3)
  y = np.array(y, dtype=np.int32)

  print('X.shape:', X.shape) 
  print('y.shape:', y.shape)

  return X, y

deam_features, sample_y = build_X_y(deam_features_data, sample_labels)
# Out:
# X.shape: (1802, 60, 261)
# y.shape: (1802, 60, 4)

# %%
import librosa

# input: 3D matrix representation of data(data_length, frames, coeffs), time-step size (in seconds)
# output: 4D matrix representation of split into time-steps (data_length, n_time_steps, frames per timestep, coeffs)
def split_timesteps(data, time_step=0.5):
    n_frames = data.shape[1]
    time_step_size = librosa.time_to_frames(time_step, sr=22050, hop_length=512)
    n_time_steps = math.floor(n_frames / time_step_size)
    
    print(f'Total no. of frames per data point: {n_frames}')
    print(f'No. of time steps: {n_time_steps}')
    print(f'No. of frames per time step: {time_step_size}')
    
    new_data = np.empty([data.shape[0], n_time_steps, time_step_size, data.shape[2]])
    
    frame_idxes = np.arange(0, n_frames, time_step_size)[:n_time_steps]
    for data_i in range(data.shape[0]):
        data_pt = np.empty([n_time_steps, time_step_size, data.shape[2]])
        for i, frame_idx in enumerate(frame_idxes):
            start_frame = frame_idx
            end_frame = frame_idx + time_step_size
            if end_frame > n_frames: 
                break
            data_pt[i] = data[data_i][start_frame:end_frame, :]
        new_data[data_i] = data_pt
    return new_data

split_mfcc = split_timesteps(mfcc_data, time_step=0.5)
split_mfcc.shape
# Out:
# /opt/conda/lib/python3.6/site-packages/librosa/util/decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import of 'jit' requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit
# Total no. of frames per data point: 1920
# No. of time steps: 91
# No. of frames per time step: 21
# (1802, 91, 21, 20)

# %%
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit

sss = StratifiedShuffleSplit(n_splits=5, test_size=0.2, random_state=20)

temp_y = []
idx = np.arange(deam_features.shape[0])
for i in range(1802):
    not_one_hot = sample_y[i].argmax(axis=1).tolist()
    most_common_no = max(set(not_one_hot), key = not_one_hot.count)
    temp_y.append(most_common_no)
temp_y = np.array(temp_y)


for train_index, test_index in sss.split(idx, temp_y):
    X_idx_trn, X_idx_test = idx[train_index], idx[test_index]
    sample_y_trn, sample_y_test = sample_y[train_index], sample_y[test_index]
    single_y_trn, single_y_test = y[train_index], y[test_index]

trn_temp_y = temp_y[X_idx_trn]
for train_index, valid_index in sss.split(X_idx_trn, trn_temp_y):
    X_idx_train, X_idx_valid = X_idx_trn[train_index], X_idx_trn[valid_index]
    sample_y_train, sample_y_valid = sample_y_trn[train_index], sample_y_trn[valid_index]  
    single_y_train, single_y_valid = single_y_trn[train_index], single_y_trn[valid_index]  
    
deam_train, deam_valid, deam_test = deam_features[X_idx_train], deam_features[X_idx_valid], deam_features[X_idx_test]
mfcc_train, mfcc_valid, mfcc_test = split_mfcc[X_idx_train], split_mfcc[X_idx_valid], split_mfcc[X_idx_test]
mfcc_train, mfcc_valid, mfcc_test = mfcc_train[:, -60:, :], mfcc_valid[:, -60:, :], mfcc_test[:, -60:, :]

# %%
deam_train.shape
# Out:
# (1152, 60, 261)

# %%
mfcc_train.shape
# Out:
# (1152, 60, 21, 20)

# %%
from sklearn.metrics import classification_report, roc_auc_score, accuracy_score, confusion_matrix
from sklearn.preprocessing import OneHotEncoder

def performance_review(model, x_test, y_test, y_pred):
    print('Test accuracy: ', accuracy_score(y_test, y_pred))
    
    print('Classification Report: \n', classification_report(y_test, y_pred))

#     print('Area under Receiver Operating Characteristic curve (ROC-AUC score)', 
#           roc_auc_score(y_test_encoded, y_pred_encoded, multi_class='ovo'))

# %%
from functools import partial
from tensorflow.keras.layers import (Conv1D, MaxPooling1D, 
                                     TimeDistributed, LSTM,
                                     Flatten, Dense, Dropout, concatenate,
                                     RepeatVector, LeakyReLU,
                                     LayerNormalization, BatchNormalization)

leaky_relu = LeakyReLU(alpha=0.05)
conv_layer = partial(Conv1D, kernel_size=4, activation=leaky_relu, padding='SAME', strides=1)
pooling = partial(MaxPooling1D, pool_size=3, strides=3, padding='SAME')

cnn_input_shape = (mfcc_train.shape[1], mfcc_train.shape[2], mfcc_train.shape[3])
mfcc_input =  keras.Input(shape=cnn_input_shape, name='mfcc')
x = TimeDistributed(LayerNormalization())(mfcc_input)
x = TimeDistributed(conv_layer(input_shape=cnn_input_shape, filters=32, kernel_size=6))(x)
x = TimeDistributed(pooling())(x)
x = TimeDistributed(conv_layer(filters=64))(x)
x = TimeDistributed(pooling())(x)
x = TimeDistributed(conv_layer(filters=64))(x)
x = TimeDistributed(pooling())(x)
x = TimeDistributed(Flatten())(x)
mfcc_output = Dense(256, activation=leaky_relu)(x)

opensmile_input_shape = (deam_train.shape[1], deam_train.shape[2])
opensmile_input = keras.Input(shape=opensmile_input_shape, name='opensmile')
combined_x = concatenate([mfcc_output, opensmile_input])
x = LSTM(128, input_shape=(combined_x.shape[1], combined_x.shape[2]), return_sequences=True)(combined_x)
x = LSTM(128, return_sequences=True)(x)
x = keras.layers.Dense(256, activation='relu')(x)
x = keras.layers.Dropout(0.5)(x)
mood_pred = keras.layers.Dense(4, activation='softmax')(x)

cat_model = keras.Model(inputs=[mfcc_input, opensmile_input], outputs=mood_pred)

optimizer = keras.optimizers.Nadam(lr=0.00005)

cat_model.compile(optimizer=optimizer, 
                    loss='categorical_crossentropy', 
                    metrics=['accuracy'])

cat_model.fit({'mfcc': mfcc_train, 'opensmile': deam_train}, 
          sample_y_train,
          validation_data=({'mfcc': mfcc_valid, 'opensmile': deam_valid}, sample_y_valid),
          batch_size=32, 
          epochs=50)
# Out:
# Epoch 1/50
# 36/36 [==============================] - 2s 50ms/step - loss: 1.3948 - accuracy: 0.2635 - val_loss: 1.3184 - val_accuracy: 0.4180
# Epoch 2/50
# 36/36 [==============================] - 1s 28ms/step - loss: 1.2974 - accuracy: 0.4041 - val_loss: 1.2602 - val_accuracy: 0.4567
# Epoch 3/50
# 36/36 [==============================] - 1s 28ms/step - loss: 1.2648 - accuracy: 0.4346 - val_loss: 1.2404 - val_accuracy: 0.4783
# Epoch 4/50
# 36/36 [==============================] - 1s 27ms/step - loss: 1.2496 - accuracy: 0.4499 - val_loss: 1.2302 - val_accuracy: 0.4893
# 36/36 [==============================] - 1s 27ms/step - loss: 1.0269 - accuracy: 0.6006 - val_loss: 1.0691 - val_accuracy: 0.5909
# Epoch 45/50
# 36/36 [==============================] - 1s 26ms/step - loss: 1.0276 - accuracy: 0.6000 - val_loss: 1.0651 - val_accuracy: 0.5939
# Epoch 46/50
# 36/36 [==============================] - 1s 26ms/step - loss: 1.0227 - accuracy: 0.6028 - val_loss: 1.0621 - val_accuracy: 0.5977
# Epoch 47/50
# 36/36 [==============================] - 1s 27ms/step - loss: 1.0450 - accuracy: 0.5898 - val_loss: 1.0673 - val_accuracy: 0.5898
# Epoch 48/50
# 36/36 [==============================] - 1s 27ms/step - loss: 1.0181 - accuracy: 0.6038 - val_loss: 1.0673 - val_accuracy: 0.5925
# Epoch 49/50
# 36/36 [==============================] - 1s 28ms/step - loss: 1.0174 - accuracy: 0.6061 - val_loss: 1.0684 - val_accuracy: 0.5887
# Epoch 50/50
# 36/36 [==============================] - 1s 27ms/step - loss: 1.0167 - accuracy: 0.6047 - val_loss: 1.0640 - val_accuracy: 0.5919

# %%
test_loss, test_acc = cat_model.evaluate({'mfcc': mfcc_test, 'opensmile': deam_test}, sample_y_test, verbose=2)
# print('\nTest accuracy:', test_acc)

y_pred = cat_model.predict({'mfcc': mfcc_test, 'opensmile': deam_test})
sample_y_test_reshape = np.argmax(sample_y_test, axis=2)
sample_y_test_reshape = sample_y_test_reshape.flatten();
y_pred_reshape = np.argmax(y_pred, axis=2)
y_pred_reshape = y_pred_reshape.flatten()
print(y_pred.shape)

performance_review(cat_model, {'mfcc': mfcc_test, 'opensmile': deam_test}, sample_y_test_reshape, y_pred_reshape)

encoded_y_pred = y_pred.reshape(y_pred.shape[0] * y_pred.shape[1], y_pred.shape[2])
print('ROC-AUC score: ', roc_auc_score(sample_y_test_reshape, encoded_y_pred, multi_class='ovr'))
# Out:
# 12/12 - 0s - loss: 1.0976 - accuracy: 0.5777
# (361, 60, 4)
# Test accuracy:  0.5777008310249307
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.57      0.87      0.68      8629
#            1       0.46      0.02      0.04      2527
#            2       0.08      0.00      0.00      3391
#            3       0.61      0.70      0.65      7113
#
#     accuracy                           0.58     21660
#    macro avg       0.43      0.40      0.34     21660
# weighted avg       0.49      0.58      0.49     21660
#
# ROC-AUC score:  0.707197515917218

# %% [markdown]
# ### Regression w/ original valence + arousal values per song

# %%
pooling = partial(MaxPooling1D, pool_size=4, strides=4, padding='SAME')

cnn_input_shape = (mfcc_train.shape[1], mfcc_train.shape[2], mfcc_train.shape[3])
mfcc_input =  keras.Input(shape=cnn_input_shape, name='mfcc')
x = TimeDistributed(LayerNormalization())(mfcc_input)
x = TimeDistributed(conv_layer(input_shape=cnn_input_shape, filters=32, kernel_size=8))(x)
x = TimeDistributed(pooling())(x)
x = TimeDistributed(conv_layer(filters=64))(x)
x = TimeDistributed(pooling())(x)
x = TimeDistributed(conv_layer(filters=64))(x)
x = TimeDistributed(pooling())(x)
x = TimeDistributed(Flatten())(x)
mfcc_output = Dense(256, activation=leaky_relu)(x)

opensmile_input_shape = (deam_train.shape[1], deam_train.shape[2])
opensmile_input = keras.Input(shape=opensmile_input_shape, name='opensmile')
combined_x = concatenate([mfcc_output, opensmile_input])
x = LSTM(128, return_sequences=True, input_shape=(combined_x.shape[1],combined_x.shape[2]))(combined_x)
x = LSTM(128)(x)
x = keras.layers.Dense(256, activation=leaky_relu)(x)
x = keras.layers.Dropout(0.5)(x)
mood_pred = keras.layers.Dense(2)(x)

optimizer = keras.optimizers.Nadam(lr=0.00008)


reg_model = keras.Model(inputs=[mfcc_input, opensmile_input], outputs=mood_pred)
reg_model.compile(loss='mae', optimizer=optimizer, metrics=['mean_squared_error'])

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_mean_squared_error', patience=20)

reg_model.fit({'mfcc': mfcc_train, 'opensmile': deam_train}, 
          single_y_train,
          validation_data=({'mfcc': mfcc_valid, 'opensmile': deam_valid}, single_y_valid),
          batch_size=32, 
          epochs=100,
          callbacks=early_stopping)
# Out:
# Epoch 1/100
# 36/36 [==============================] - 2s 46ms/step - loss: 4.5164 - mean_squared_error: 22.0590 - val_loss: 3.9163 - val_mean_squared_error: 16.8437
# Epoch 2/100
# 36/36 [==============================] - 1s 26ms/step - loss: 2.3131 - mean_squared_error: 7.6625 - val_loss: 1.0009 - val_mean_squared_error: 1.4682
# Epoch 3/100
# 36/36 [==============================] - 1s 26ms/step - loss: 1.1866 - mean_squared_error: 2.1262 - val_loss: 0.9745 - val_mean_squared_error: 1.4078
# Epoch 4/100
# 36/36 [==============================] - 1s 26ms/step - loss: 1.1552 - mean_squared_error: 2.0209 - val_loss: 0.9778 - val_mean_squared_error: 1.4137
# Epoch 5/100
# 36/36 [==============================] - 1s 26ms/step - loss: 1.1400 - mean_squared_error: 1.9614 - val_loss: 0.9684 - val_mean_squared_error: 1.3914
# Epoch 6/100
# 36/36 [==============================] - 1s 26ms/step - loss: 1.1532 - mean_squared_error: 2.0287 - val_loss: 0.9607 - val_mean_squared_error: 1.3719
# Epoch 7/100
# 36/36 [==============================] - 1s 26ms/step - loss: 1.1253 - mean_squared_error: 1.9050 - val_loss: 0.9630 - val_mean_squared_error: 1.3766
# Epoch 8/100
# 36/36 [==============================] - 1s 26ms/step - loss: 1.1268 - mean_squared_error: 1.9324 - val_loss: 0.9643 - val_mean_squared_error: 1.3781
# Epoch 9/100
# 36/36 [==============================] - 1s 26ms/step - loss: 1.1111 - mean_squared_error: 1.8590 - val_loss: 0.9564 - val_mean_squared_error: 1.3544
# Epoch 10/100
# 36/36 [==============================] - 1s 26ms/step - loss: 1.1140 - mean_squared_error: 1.8804 - val_loss: 0.9532 - val_mean_squared_error: 1.3469
# Epoch 11/100
# 36/36 [==============================] - 1s 26ms/step - loss: 1.1144 - mean_squared_error: 1.9012 - val_loss: 0.9460 - val_mean_squared_error: 1.3276
# Epoch 12/100
# 36/36 [==============================] - 1s 26ms/step - loss: 1.0759 - mean_squared_error: 1.7588 - val_loss: 0.9575 - val_mean_squared_error: 1.3571
# Epoch 13/100
# 36/36 [==============================] - 1s 26ms/step - loss: 1.0941 - mean_squared_error: 1.8536 - val_loss: 0.9499 - val_mean_squared_error: 1.3390
# Epoch 14/100
# 36/36 [==============================] - 1s 26ms/step - loss: 1.0580 - mean_squared_error: 1.7161 - val_loss: 0.9386 - val_mean_squared_error: 1.3095
# Epoch 15/100
# 36/36 [==============================] - 1s 26ms/step - loss: 1.0876 - mean_squared_error: 1.7896 - val_loss: 0.9166 - val_mean_squared_error: 1.2749
# Epoch 16/100
# 36/36 [==============================] - 1s 26ms/step - loss: 1.0492 - mean_squared_error: 1.6678 - val_loss: 0.9033 - val_mean_squared_error: 1.2357
# Epoch 17/100
# 36/36 [==============================] - 1s 26ms/step - loss: 1.0382 - mean_squared_error: 1.6609 - val_loss: 0.8913 - val_mean_squared_error: 1.2114
# Epoch 18/100
# 36/36 [==============================] - 1s 26ms/step - loss: 1.0100 - mean_squared_error: 1.5851 - val_loss: 0.8925 - val_mean_squared_error: 1.2189
# Epoch 19/100
# 36/36 [==============================] - 1s 26ms/step - loss: 1.0068 - mean_squared_error: 1.5870 - val_loss: 0.8806 - val_mean_squared_error: 1.2025
# Epoch 20/100
# 36/36 [==============================] - 1s 26ms/step - loss: 0.9918 - mean_squared_error: 1.5360 - val_loss: 0.8944 - val_mean_squared_error: 1.2348
# Epoch 21/100
# 36/36 [==============================] - 1s 26ms/step - loss: 1.0064 - mean_squared_error: 1.5989 - val_loss: 0.8862 - val_mean_squared_error: 1.2193
# Epoch 22/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.9872 - mean_squared_error: 1.5319 - val_loss: 0.9201 - val_mean_squared_error: 1.3105
# Epoch 23/100
# 36/36 [==============================] - 1s 26ms/step - loss: 0.9837 - mean_squared_error: 1.5253 - val_loss: 0.9112 - val_mean_squared_error: 1.3098
# Epoch 24/100
# 36/36 [==============================] - 1s 25ms/step - loss: 0.9818 - mean_squared_error: 1.5023 - val_loss: 0.8812 - val_mean_squared_error: 1.2229
# Epoch 25/100
# 36/36 [==============================] - 1s 26ms/step - loss: 0.9707 - mean_squared_error: 1.4479 - val_loss: 0.8878 - val_mean_squared_error: 1.2263
# Epoch 26/100
# 36/36 [==============================] - 1s 26ms/step - loss: 0.9623 - mean_squared_error: 1.4540 - val_loss: 0.8734 - val_mean_squared_error: 1.1790
# Epoch 27/100
# 36/36 [==============================] - 1s 25ms/step - loss: 0.9660 - mean_squared_error: 1.4639 - val_loss: 0.8835 - val_mean_squared_error: 1.2256
# Epoch 28/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.9556 - mean_squared_error: 1.4285 - val_loss: 0.8643 - val_mean_squared_error: 1.1692
# Epoch 29/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.9403 - mean_squared_error: 1.3744 - val_loss: 0.8583 - val_mean_squared_error: 1.1391
# Epoch 30/100
# 36/36 [==============================] - 1s 26ms/step - loss: 0.9638 - mean_squared_error: 1.4108 - val_loss: 0.8619 - val_mean_squared_error: 1.1602
# Epoch 31/100
# 36/36 [==============================] - 1s 26ms/step - loss: 0.9409 - mean_squared_error: 1.3616 - val_loss: 0.8634 - val_mean_squared_error: 1.1723
# Epoch 32/100
# Epoch 69/100
# 36/36 [==============================] - 1s 26ms/step - loss: 0.8579 - mean_squared_error: 1.1811 - val_loss: 0.7919 - val_mean_squared_error: 0.9898
# Epoch 70/100
# 36/36 [==============================] - 1s 26ms/step - loss: 0.8565 - mean_squared_error: 1.1961 - val_loss: 0.8050 - val_mean_squared_error: 0.9969
# Epoch 71/100
# 36/36 [==============================] - 1s 25ms/step - loss: 0.8461 - mean_squared_error: 1.1619 - val_loss: 0.7998 - val_mean_squared_error: 1.0238
# Epoch 72/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.8514 - mean_squared_error: 1.1777 - val_loss: 0.7980 - val_mean_squared_error: 1.0042
# Epoch 73/100
# 36/36 [==============================] - 1s 26ms/step - loss: 0.8513 - mean_squared_error: 1.1473 - val_loss: 0.7869 - val_mean_squared_error: 0.9868
# Epoch 74/100
# 36/36 [==============================] - 1s 25ms/step - loss: 0.8507 - mean_squared_error: 1.1532 - val_loss: 0.7879 - val_mean_squared_error: 0.9930
# Epoch 75/100
# 36/36 [==============================] - 1s 26ms/step - loss: 0.8512 - mean_squared_error: 1.1527 - val_loss: 0.7814 - val_mean_squared_error: 0.9753
# Epoch 76/100
# 36/36 [==============================] - 1s 25ms/step - loss: 0.8435 - mean_squared_error: 1.1550 - val_loss: 0.7882 - val_mean_squared_error: 0.9818
# Epoch 77/100
# 36/36 [==============================] - 1s 25ms/step - loss: 0.8327 - mean_squared_error: 1.1181 - val_loss: 0.7871 - val_mean_squared_error: 0.9868
# Epoch 78/100
# 36/36 [==============================] - 1s 25ms/step - loss: 0.8354 - mean_squared_error: 1.1132 - val_loss: 0.7959 - val_mean_squared_error: 1.0135
# Epoch 79/100
# 36/36 [==============================] - 1s 25ms/step - loss: 0.8421 - mean_squared_error: 1.1522 - val_loss: 0.8036 - val_mean_squared_error: 1.0278
# Epoch 80/100
# 36/36 [==============================] - 1s 25ms/step - loss: 0.8418 - mean_squared_error: 1.1456 - val_loss: 0.8168 - val_mean_squared_error: 1.0548
# Epoch 81/100
# 36/36 [==============================] - 1s 26ms/step - loss: 0.8459 - mean_squared_error: 1.1520 - val_loss: 0.8071 - val_mean_squared_error: 1.0287
# Epoch 82/100
# 36/36 [==============================] - 1s 25ms/step - loss: 0.8383 - mean_squared_error: 1.1255 - val_loss: 0.7892 - val_mean_squared_error: 0.9879
# Epoch 83/100
# 36/36 [==============================] - 1s 25ms/step - loss: 0.8496 - mean_squared_error: 1.1502 - val_loss: 0.7900 - val_mean_squared_error: 0.9880
# Epoch 84/100
# 36/36 [==============================] - 1s 26ms/step - loss: 0.8269 - mean_squared_error: 1.1100 - val_loss: 0.8084 - val_mean_squared_error: 1.0317
# Epoch 85/100
# 36/36 [==============================] - 1s 26ms/step - loss: 0.8372 - mean_squared_error: 1.1287 - val_loss: 0.8112 - val_mean_squared_error: 1.0336
# Epoch 86/100
# 36/36 [==============================] - 1s 26ms/step - loss: 0.8278 - mean_squared_error: 1.1261 - val_loss: 0.8353 - val_mean_squared_error: 1.0717
# Epoch 87/100
# 36/36 [==============================] - 1s 25ms/step - loss: 0.8427 - mean_squared_error: 1.1333 - val_loss: 0.7999 - val_mean_squared_error: 1.0102
# Epoch 88/100
# 36/36 [==============================] - 1s 27ms/step - loss: 0.8335 - mean_squared_error: 1.1322 - val_loss: 0.8085 - val_mean_squared_error: 1.0225
# Epoch 89/100
# 36/36 [==============================] - 1s 26ms/step - loss: 0.8332 - mean_squared_error: 1.1059 - val_loss: 0.8405 - val_mean_squared_error: 1.0850
# Epoch 90/100
# 36/36 [==============================] - 1s 25ms/step - loss: 0.8169 - mean_squared_error: 1.0751 - val_loss: 0.7946 - val_mean_squared_error: 0.9855
# Epoch 91/100
# 36/36 [==============================] - 1s 26ms/step - loss: 0.8433 - mean_squared_error: 1.1471 - val_loss: 0.7894 - val_mean_squared_error: 0.9868
# Epoch 92/100
# 36/36 [==============================] - 1s 25ms/step - loss: 0.8241 - mean_squared_error: 1.0967 - val_loss: 0.7928 - val_mean_squared_error: 0.9914
# Epoch 93/100
# 36/36 [==============================] - 1s 26ms/step - loss: 0.8329 - mean_squared_error: 1.1220 - val_loss: 0.7947 - val_mean_squared_error: 0.9889
# Epoch 94/100
# 36/36 [==============================] - 1s 26ms/step - loss: 0.8398 - mean_squared_error: 1.1371 - val_loss: 0.7854 - val_mean_squared_error: 0.9896
# Epoch 95/100
# 36/36 [==============================] - 1s 26ms/step - loss: 0.8323 - mean_squared_error: 1.1023 - val_loss: 0.7782 - val_mean_squared_error: 0.9763

# %%
from sklearn.metrics import accuracy_score

def categorize_val_arousal(data):
    cat_data = []
    # A: active, P: passive
    # P: positive, N: negative
    for point in data:
        valence, arousal = point[0], point[1]
        if valence >= 5 and arousal >= 5:
            cat_data.append('AP')
        elif valence < 5 and arousal >= 5:
            cat_data.append('AN')
        elif valence >= 5 and arousal < 5:
            cat_data.append('PP')
        elif valence < 5 and arousal < 5:
            cat_data.append('PN')
    return np.array(cat_data, dtype='str')


score = reg_model.evaluate({'mfcc': mfcc_test, 'opensmile': deam_test}, single_y_test)
print(f'Test reg RMSE: {list(map(math.sqrt, score))}')
y_pred = reg_model.predict({'mfcc': mfcc_test, 'opensmile': deam_test})

cat_y_pred = categorize_val_arousal(y_pred)
cat_y_test = categorize_val_arousal(single_y_test)

performance_review(reg_model, {'mfcc': mfcc_test, 'opensmile': deam_test}, cat_y_test, cat_y_pred)
# Out:
# 12/12 [==============================] - 0s 7ms/step - loss: 0.8064 - mean_squared_error: 1.0546
# Test reg RMSE: [0.8979738448864525, 1.026959075272053]
# Test accuracy:  0.6177285318559557
# Classification Report:
#                precision    recall  f1-score   support
#
#           AN       0.00      0.00      0.00        42
#           AP       0.62      0.81      0.70       142
#           PN       0.63      0.80      0.70       132
#           PP       0.38      0.07      0.11        45
#
#     accuracy                           0.62       361
#    macro avg       0.41      0.42      0.38       361
# weighted avg       0.52      0.62      0.55       361

# %%
optimizer = keras.optimizers.Nadam(lr=0.00005)

best_model = keras.Model(inputs=[mfcc_input, opensmile_input], outputs=mood_pred)
best_model.compile(loss='mae', optimizer=optimizer, metrics=['mean_squared_error'])

mfcc_data = np.concatenate((mfcc_train, mfcc_valid, mfcc_test), axis=0)
opensmile_data = np.concatenate((deam_train, deam_valid, deam_test), axis=0)
labels = np.concatenate((single_y_train, single_y_valid, single_y_test), axis=0)

early_stopping = tf.keras.callbacks.EarlyStopping(monitor='mean_squared_error', patience=20)
best_model.fit({'mfcc': mfcc_data, 'opensmile': opensmile_data}, 
          labels,
          batch_size=32, 
          epochs=100,
          callbacks=early_stopping)
# Out:
# Epoch 1/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.8475 - mean_squared_error: 1.1501
# Epoch 2/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8558 - mean_squared_error: 1.1597
# Epoch 3/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8454 - mean_squared_error: 1.1530
# Epoch 4/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8415 - mean_squared_error: 1.1195
# Epoch 5/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8350 - mean_squared_error: 1.1196
# Epoch 6/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8294 - mean_squared_error: 1.1008
# Epoch 7/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8460 - mean_squared_error: 1.1410
# Epoch 8/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8349 - mean_squared_error: 1.1248
# Epoch 9/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8411 - mean_squared_error: 1.1280
# Epoch 10/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8428 - mean_squared_error: 1.1409
# Epoch 11/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8258 - mean_squared_error: 1.0943
# Epoch 12/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8228 - mean_squared_error: 1.0816
# Epoch 13/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8356 - mean_squared_error: 1.1261
# Epoch 14/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8449 - mean_squared_error: 1.1292
# Epoch 15/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8234 - mean_squared_error: 1.0928
# Epoch 16/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8219 - mean_squared_error: 1.0783
# Epoch 17/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8380 - mean_squared_error: 1.1234
# Epoch 18/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8265 - mean_squared_error: 1.0953
# Epoch 19/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8288 - mean_squared_error: 1.1035
# Epoch 20/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8412 - mean_squared_error: 1.1170
# Epoch 21/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8254 - mean_squared_error: 1.0940
# Epoch 22/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8301 - mean_squared_error: 1.0925
# Epoch 23/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8292 - mean_squared_error: 1.1010
# Epoch 24/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8283 - mean_squared_error: 1.1062
# Epoch 25/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8287 - mean_squared_error: 1.0996
# Epoch 26/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8341 - mean_squared_error: 1.1143
# Epoch 27/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8249 - mean_squared_error: 1.0890
# Epoch 28/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8378 - mean_squared_error: 1.1246
# Epoch 29/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8292 - mean_squared_error: 1.1039
# Epoch 30/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8150 - mean_squared_error: 1.0664
# Epoch 31/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8339 - mean_squared_error: 1.1094
# Epoch 32/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8146 - mean_squared_error: 1.0646
# Epoch 33/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8227 - mean_squared_error: 1.0908
# Epoch 34/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8019 - mean_squared_error: 1.0511
# Epoch 35/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8159 - mean_squared_error: 1.0842
# Epoch 36/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8234 - mean_squared_error: 1.0863
# Epoch 37/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8112 - mean_squared_error: 1.0695
# Epoch 38/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8147 - mean_squared_error: 1.0820
# Epoch 39/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8189 - mean_squared_error: 1.0724
# Epoch 40/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8095 - mean_squared_error: 1.0673
# Epoch 41/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8099 - mean_squared_error: 1.0536
# Epoch 42/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8185 - mean_squared_error: 1.0747
# Epoch 43/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8189 - mean_squared_error: 1.0799
# Epoch 44/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8107 - mean_squared_error: 1.0590
# Epoch 45/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8103 - mean_squared_error: 1.0540
# Epoch 46/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8139 - mean_squared_error: 1.0510
# Epoch 47/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8103 - mean_squared_error: 1.0544
# Epoch 48/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8101 - mean_squared_error: 1.0435
# Epoch 49/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8110 - mean_squared_error: 1.0567
# Epoch 50/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8099 - mean_squared_error: 1.0465
# Epoch 51/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8039 - mean_squared_error: 1.0461
# Epoch 52/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8097 - mean_squared_error: 1.0545
# Epoch 53/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8130 - mean_squared_error: 1.0721
# Epoch 54/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8144 - mean_squared_error: 1.0685
# Epoch 55/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8119 - mean_squared_error: 1.0583
# Epoch 56/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8104 - mean_squared_error: 1.0616
# Epoch 57/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8063 - mean_squared_error: 1.0510
# Epoch 58/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.7993 - mean_squared_error: 1.0321
# Epoch 59/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8055 - mean_squared_error: 1.0578
# Epoch 60/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8069 - mean_squared_error: 1.0569
# Epoch 61/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8041 - mean_squared_error: 1.0527
# Epoch 62/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8084 - mean_squared_error: 1.0580
# Epoch 63/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8074 - mean_squared_error: 1.0464
# Epoch 64/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8031 - mean_squared_error: 1.0378
# Epoch 65/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.7999 - mean_squared_error: 1.0421
# Epoch 66/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.7976 - mean_squared_error: 1.0316
# Epoch 67/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.7919 - mean_squared_error: 1.0160
# Epoch 68/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.7958 - mean_squared_error: 1.0193
# Epoch 69/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8020 - mean_squared_error: 1.0463
# Epoch 70/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.7845 - mean_squared_error: 1.0043
# Epoch 71/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.7993 - mean_squared_error: 1.0281
# Epoch 72/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8015 - mean_squared_error: 1.0484
# Epoch 73/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8010 - mean_squared_error: 1.0461
# Epoch 74/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.7960 - mean_squared_error: 1.0246
# Epoch 75/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.7923 - mean_squared_error: 1.0183
# Epoch 76/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.7955 - mean_squared_error: 1.0325
# Epoch 77/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.7939 - mean_squared_error: 1.0244
# Epoch 78/100
# 57/57 [==============================] - 1s 18ms/step - loss: 0.7830 - mean_squared_error: 1.0025
# Epoch 79/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.8010 - mean_squared_error: 1.0251
# Epoch 80/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.7795 - mean_squared_error: 0.9973
# Epoch 81/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.7915 - mean_squared_error: 1.0125
# Epoch 82/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.7819 - mean_squared_error: 0.9987
# Epoch 83/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.7826 - mean_squared_error: 0.9945
# Epoch 84/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.7906 - mean_squared_error: 1.0057
# Epoch 85/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.7958 - mean_squared_error: 1.0156
# Epoch 86/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.7814 - mean_squared_error: 0.9930
# Epoch 87/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.7834 - mean_squared_error: 1.0087
# Epoch 88/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.7855 - mean_squared_error: 1.0235
# Epoch 89/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.7892 - mean_squared_error: 1.0082
# Epoch 90/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.7842 - mean_squared_error: 0.9967
# Epoch 91/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.7908 - mean_squared_error: 1.0139
# Epoch 92/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.7898 - mean_squared_error: 1.0095
# Epoch 93/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.7840 - mean_squared_error: 1.0112
# Epoch 94/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.7879 - mean_squared_error: 1.0224
# Epoch 95/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.7905 - mean_squared_error: 1.0184
# Epoch 96/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.7930 - mean_squared_error: 1.0218
# Epoch 97/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.7938 - mean_squared_error: 1.0135
# Epoch 98/100
# 57/57 [==============================] - 1s 17ms/step - loss: 0.7867 - mean_squared_error: 1.0221
# Epoch 99/100
# 57/57 [==============================] - 1s 18ms/step - loss: 0.7881 - mean_squared_error: 1.0065
# Epoch 100/100
# 57/57 [==============================] - 1s 18ms/step - loss: 0.7800 - mean_squared_error: 0.9923

# %%
performance_review(best_model, {'mfcc': mfcc_test, 'opensmile': deam_test}, cat_y_test, cat_y_pred)

# save the model
best_model.save('reg_model')
# Out:
# Test accuracy:  0.5983379501385041
# Classification Report:
#                precision    recall  f1-score   support
#
#           AN       0.00      0.00      0.00        42
#           AP       0.62      0.75      0.68       142
#           PN       0.62      0.83      0.71       132
#           PP       0.10      0.02      0.04        45
#
#     accuracy                           0.60       361
#    macro avg       0.33      0.40      0.35       361
# weighted avg       0.48      0.60      0.53       361
#
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: reg_model/assets
